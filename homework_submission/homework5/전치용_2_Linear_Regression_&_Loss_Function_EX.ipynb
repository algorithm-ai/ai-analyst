# %% [markdown]
# ##  Linear Regression & Loss Function

# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ## 문제 1 Grid Search를 활용한 Linear Regression
#
# linear regression 과 **Grid Search**  을 이용해 아래 데이터를 linear regression 해주세요.

# %% [markdown]
# ###  Grid Search
#
#
# 1. 탐색할 가중치 조합을 구성합니다. 이 때 `np.meshgrid` 혹은 `np.mgrid`로 구성합니다.
#
# 2. 위의 가중치 조합에서 가중치를 뽑아, 예측값을 산출합니다.
#
# 3. 실제 값과 예측값의 차이를 MSE로 계산합니다.
#
# 3. 모든 가중치 조합 중 가장 작은 MSE를 보이는 Loss값 조합을 찾습니다.

# %%
# 아래 코드를 실행해 주세요 
num_points = 1000
vectors_set = []
for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

xs = np.asarray([v[0] for v in vectors_set])
ys = np.asarray([v[1] for v in vectors_set])

plt.plot(xs, ys, 'ro', label='Original data')
plt.legend()
plt.show()

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요

# %%
# 정답을 서술해주세요!
W0s = np.linspace(0,2,100)
W1s = np.linspace(0,1,100)

points = np.stack(np.meshgrid(W0s,W1s),axis=-1) # 가중치 조합 만들기 #meshgrid 로 차원수를 늘려준다
points = points.reshape(-1,2)
points

def calculate_MSE(W0, W1):
    y_true = ys # 실제값
    y_pred = W1*xs+W0 # 가중치 조합을 통한 예측값
    return ((y_true - y_pred)**2).mean() # MSE

losses = []
for W0, W1 in points:
    loss = calculate_MSE(W0, W1)
    losses.append(loss)
losses = np.array(losses)


import pandas as pd
result = pd.DataFrame(points)
result['loss'] = losses
W0s, W1s, _ = result.sort_values('loss').iloc[0]
plt.plot(xs, ys, 'ro',label='Original data') #color ='red', marker ='o', label='Original data')

plt.plot(xs, W1s_*xs+W0s_)

# %% [markdown]
# #### 정답 확인
# * 아래와 같이 출력이 나오도록 해주세요
#
# ![Imgur](https://i.imgur.com/zEiW7zM.png)

# %% [markdown]
# ## 문제 2
#
# 문제 1과 동일합니다. 다만 Loss function은 MAE(mean absolute Error)을 사용합니다 <br>
# 아래와 같은 그림이 나올수 있도록 Linear Regression 결과를 시각화 해주세요

# %%
# 아래 코드를 실행해 주세요 
num_points = 1000
vectors_set = []
for i in range(num_points):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])

xs = np.asarray([v[0] for v in vectors_set])
ys = np.asarray([v[1] for v in vectors_set])

plt.plot(xs, ys, 'ro', label='Original data')
plt.legend()
plt.show()

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요

# %%
# 정답을 서술해 주세요!
W0s = np.linspace(0,2,100)
W1s = np.linspace(0,1,100)

points = np.stack(np.meshgrid(W0s,W1s),axis=-1) # 가중치 조합 만들기 #meshgrid 로 차원수를 늘려준다
points = points.reshape(-1,2)
points

def calculate_MAE(W0, W1):
    y_true = ys # 실제값
    y_pred = W1*xs+W0 # 가중치 조합을 통한 예측값
    return (abs(y_true - y_pred)).mean() # MAE

losses = []
for W0, W1 in points:
    loss = calculate_MAE(W0, W1)
    losses.append(loss)
losses = np.array(losses)


import pandas as pd
result = pd.DataFrame(points)
result['loss'] = losses
W0s, W1s, _ = result.sort_values('loss').iloc[0]
plt.plot(xs, ys, 'ro', label='Original data')

plt.plot(xs, W1s_*xs+W0s_)

# %% [markdown]
# #### 정답 확인
# * 아래와 같이 출력이 나오도록 해주세요
#
# ![Imgur](https://i.imgur.com/ycO3RGp.png)
