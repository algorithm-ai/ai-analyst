# %% [markdown]
# ## Tensor을 연산하는 함수들

# %%
# %matplotlib inline
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import pandas as pd

tf.enable_eager_execution()
np.set_printoptions(formatter={
    'float_kind': lambda x: "{0:0.3f}".format(x)})

# %%
## 예제 데이터 )  califonia housing price

MedInc : 행정 구역 내 소득의 중앙값<br>
HouseAge : 행정 구역 내 주택 연식의 중앙값<br>
AveRooms : 평균 방 갯수<br>
AveBedrms : 평균 침실 갯수<br>
Population : 행정 구역 내 인구 수<br>
AveOccup : 평균 자가 비율<br>
Latitude : 해당 행정 구역의 위도<br>
Longitude : 해당 행정 구역의 경도<br>
# Out:
#   File "<ipython-input-4-adf71426b854>", line 2
#     MedInc : 행정 구역 내 소득의 중앙값<br>
#                  ^
# SyntaxError: invalid syntax

# %%
from sklearn.datasets import fetch_california_housing
california = fetch_california_housing()

clf_data = california.data

df = pd.DataFrame(california.data,columns=california.feature_names)
df.head()
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data
# WARNING: Logging before flag parsing goes to stderr.
# I0711 05:01:45.535058 139998693242752 california_housing.py:114] Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]

# %% [markdown]
#  ## 문제 1. 평균, 표준편차, 최소값, 최대값 구하기
#
# + 각 열의 평균, 표준편차, 최소값, 최대값순으로 합쳐진 행렬을 구해주세요. <br>
# 그리고 shape=(4,8) 으로 만들어  answer1 에 담아주세요.

# %%
# 우선 실행해주세요
tf_data = tf.constant(df.values)
tf_data
# Out:
# <tf.Tensor: id=0, shape=(20640, 8), dtype=float64, numpy=
# array([[8.325, 41.000, 6.984, ..., 2.556, 37.880, -122.230],
#        [8.301, 21.000, 6.238, ..., 2.110, 37.860, -122.220],
#        [7.257, 52.000, 8.288, ..., 2.802, 37.850, -122.240],
#        ...,
#        [1.700, 17.000, 5.206, ..., 2.326, 39.430, -121.220],
#        [1.867, 18.000, 5.330, ..., 2.123, 39.430, -121.320],
#        [2.389, 16.000, 5.255, ..., 2.617, 39.370, -121.240]])>

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요
# * 결과는 `answer1`에 담아주세요

# %%
mean_value = tf.reduce_mean(tf_data,axis=0)
std_value = df.std(axis=0)
min_value = tf.reduce_min(tf_data,axis=0)
max_value = tf.reduce_max(tf_data,axis=0)


answer1 = tf.stack([ mean_value, std_value, min_value, max_value ],axis=0)
# Out:
# <tf.Tensor: id=19, shape=(), dtype=float64, numpy=172.95567358137987>

# %% [markdown]
# #### 정답 확인
# * 정답을 입력한 후, 아래를 실행시키면 정답인지 확인합니다.

# %%
from numpy.testing import assert_array_almost_equal

assert 'answer1' in globals(), "결과를 answer1 변수에 담아주세요!"

A = pd.concat([df.mean(),df.std(),df.min(),df.max()],axis=1).values.T

if "numpy" in dir(answer1):
    answer1 = answer1.numpy()

assert_array_almost_equal(A, answer1,decimal=1,
                          err_msg="\n\n정답은 \n{}\n입니다. 다시 확인해 주세요".format(A))
print("정답입니다!!!")
# Out:
# 정답입니다!!!

# %% [markdown]
#  ## 문제 2. 평균 침실 갯수 정렬하기
#
# * AveBedrms의 값을 오름차순으로 정렬해 주세요.

# %%
# 우선 실행해주세요
tf_data = tf.constant(df.values)
tf_data
# Out:
# <tf.Tensor: id=41410, shape=(20640, 8), dtype=float64, numpy=
# array([[8.325, 41.000, 6.984, ..., 2.556, 37.880, -122.230],
#        [8.301, 21.000, 6.238, ..., 2.110, 37.860, -122.220],
#        [7.257, 52.000, 8.288, ..., 2.802, 37.850, -122.240],
#        ...,
#        [1.700, 17.000, 5.206, ..., 2.326, 39.430, -121.220],
#        [1.867, 18.000, 5.330, ..., 2.123, 39.430, -121.320],
#        [2.389, 16.000, 5.255, ..., 2.617, 39.370, -121.240]])>

# %% [markdown]
# #### 답안지 입력란
# * 아래에 답을 서술하여 주세요
# * 결과는 `answer2`에 담아주세요

# %%
answer2 = tf.sort(tf_data[:,3],axis=0)
answer2
# Out:
# <tf.Tensor: id=41630, shape=(20640,), dtype=float64, numpy=array([0.333, 0.375, 0.444, ..., 15.312, 25.636, 34.067])>

# %% [markdown]
# #### 정답 확인
# * 정답을 입력한 후, 아래를 실행시키면 정답인지 확인합니다.

# %%
from numpy.testing import assert_array_almost_equal

assert 'answer2' in globals(), "결과를 answer2 변수에 담아주세요!"

A = df['AveBedrms'].sort_values()

if "numpy" in dir(answer2):
    answer2 = answer2.numpy()

assert_array_almost_equal(A, answer2, decimal=1,
                          err_msg="\n\n정답은 \n{}\n입니다. 다시 확인해 주세요".format(A))
print("정답입니다!!!")
# Out:
# 정답입니다!!!
